# %%
import pandas as pd

# %%
data={"a":[1,2,3,4],"b":[4,5,6,7],"c":["asma","saba","saad","umaira"]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    a  b       c
# 0  1  4    asma
# 1  2  5    saba
# 2  3  6    saad
# 3  4  7  umaira

# %%
df.set_index('a',inplace=True)

# %%
df
# Out:
#    b       c
# a
# 1  4    asma
# 2  5    saba
# 3  6    saad
# 4  7  umaira

# %%
df=df.reset_index()

# %%
df
# Out:
#    a  b       c
# 0  1  4    asma
# 1  2  5    saba
# 2  3  6    saad
# 3  4  7  umaira

# %%
data={"a":[1,2,3,4],"b":[4,5,6,7],"c":["asma","saba","saad","umaira"]}
df1=pd.DataFrame(data,index=['a','b','c','d'])

# %%
df1
# Out:
#    a  b       c
# a  1  4    asma
# b  2  5    saba
# c  3  6    saad
# d  4  7  umaira

# %%
df1.reindex(['d','c','a','b'])
# Out:
#    a  b       c
# d  4  7  umaira
# c  3  6    saad
# a  1  4    asma
# b  2  5    saba

# %%
df1
# Out:
#    a  b       c
# a  1  4    asma
# b  2  5    saba
# c  3  6    saad
# d  4  7  umaira

# %%
df1.iterrows
# Out:
# <bound method DataFrame.iterrows of    a  b       c
# a  1  4    asma
# b  2  5    saba
# c  3  6    saad
# d  4  7  umaira>

# %% [markdown]
# #### ***use row index***

# %%
for i,j in df1.iterrows():
    print(i,j)
# Out:
# a a       1
# b       4
# c    asma
# Name: a, dtype: object
# b a       2
# b       5
# c    saba
# Name: b, dtype: object
# c a       3
# b       6
# c    saad
# Name: c, dtype: object
# d a         4
# b         7
# c    umaira
# Name: d, dtype: object

# %% [markdown]
# #### ***use column index***

# %%
for i,j in df1.items():
    print(i,j)
# Out:
# a a    1
# b    2
# c    3
# d    4
# Name: a, dtype: int64
# b a    4
# b    5
# c    6
# d    7
# Name: b, dtype: int64
# c a      asma
# b      saba
# c      saad
# d    umaira
# Name: c, dtype: str

# %%
df1
# Out:
#    a  b       c
# a  1  4    asma
# b  2  5    saba
# c  3  6    saad
# d  4  7  umaira

# %%
df['a']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
[i for i in df1['a']]
# Out:
# [1, 2, 3, 4]

# %%
df1
# Out:
#    a  b       c
# a  1  4    asma
# b  2  5    saba
# c  3  6    saad
# d  4  7  umaira

# %% [markdown]
# #### ***To find sum of all***

# %%
def test(x):
    return x.sum()
df1.apply(test,axis=0)#if wo write axis=1 it start summ row wise in this case it generate error
# Out:
# a                    10
# b                    22
# c    asmasabasaadumaira
# dtype: object

# %%
df2=df1[['a','b']]

# %%
df2
# Out:
#    a  b
# a  1  4
# b  2  5
# c  3  6
# d  4  7

# %%
df2.map(lambda x:x**2)
# Out:
#     a   b
# a   1  16
# b   4  25
# c   9  36
# d  16  49

# %%
df1
# Out:
#    a  b       c
# a  1  4    asma
# b  2  5    saba
# c  3  6    saad
# d  4  7  umaira

# %%
df1.sort_values('c')
# Out:
#    a  b       c
# a  1  4    asma
# c  3  6    saad
# b  2  5    saba
# d  4  7  umaira

# %%
df1.sort_index(ascending= False)
# Out:
#    a  b       c
# d  4  7  umaira
# c  3  6    saad
# b  2  5    saba
# a  1  4    asma

# %% [markdown]
# #### ***To chk the large data***

# %%
pd.set_option("display.max_colwidth",1000)
df3=pd.DataFrame({"desc":["Pandas me jo error aa raha tha uska simple reason yeh hai ke **naye pandas version me `applymap()` remove kar diya gaya hai**, is liye DataFrame ke liye woh method ab exist hi nahi karta. Pehle hum element-wise operation ke liye `applymap()` use karte the, lekin ab uski jagah **`map()`** use hota hai, ya agar data numeric ho to seedha **`df2 ** 2`** likhna sab se best aur fast tareeqa hota hai. Is wajah se `AttributeError` aa raha tha, aur solution yeh hai ke updated method ya vectorized operation use ki jaye.""WHILE LOOP.ipynb"
]})

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   desc
# ...

# %%
pd.set_option("display.max_colwidth",1000)
df3=pd.DataFrame({"desc":["Pandas me jo error aa raha tha uska simple reason yeh hai ke **naye pandas version me `applymap()` remove kar diya gaya hai**, is liye DataFrame ke liye woh method ab exist hi nahi karta. Pehle hum element-wise operation ke liye `applymap()` use karte the, lekin ab uski jagah **`map()`** use hota hai, ya agar data numeric ho to seedha **`df2 ** 2`** likhna sab se best aur fast tareeqa hota hai. Is wajah se `AttributeError` aa raha tha, aur solution yeh hai ke updated method ya vectorized operation use ki jaye.""WHILE LOOP.ipynb","my name is asma","i am a student"
]})

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   desc
# ...

# %%
df3['len']=df3['desc'].apply(len)

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   desc  \
# ...

# %%
df3['word_count']=df3['desc'].apply(lambda x:len(x.split()))

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   desc  \
# ...
