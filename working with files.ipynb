# %% [markdown]
# ### ***WORKING WITH FILES***

# %%
f=open("test.txt","w")

# %%
pwd
# Out:
# 'd:\\data science'

# %%
f.write("this is my first file")
f.close()

# %%
f=open("test.txt","w")
f.write("this is my file")
f.close()

# %%
f=open("test.txt","a")
f.write("its my file")
f.close()

# %%
f=open("test.txt","r")
f.read()
# Out:
# 'this is my fileits my file'

# %%
data=open("test.txt","r")
data.read()
# Out:
# 'this is my fileits my file'

# %%
data.seek(0)
# Out:
# 0

# %%
data.readline()
# Out:
# 'this is my fileits my file'

# %%
#seek is used to read the text from a particular place
data.seek(10)
data.readline()
# Out:
# ' fileits my file'

# %%
data1=open("test.txt","r")
for i in data1:
    print(i)
# Out:
# this is my fileits my file

# %%
import os
os.path.getsize("test.txt")
# Out:
# 26

# %%
os.remove("test.txt")

# %%
f=open("test2.txt","w")
f.write("hi its my second file")
# Out:
# 21

# %%
f.close()

# %%
os.rename("test2.txt","new.txt")

# %%
import shutil
shutil.copy("new.txt","copy_newnew.txt")
# Out:
# 'copy_newnew.txt'

# %%
with open("new.txt","r") as f:
    print(f.read())
# Out:
# hi its my second file
