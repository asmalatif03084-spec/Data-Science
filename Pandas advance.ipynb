# %%
import pandas as pd

# %%
df=pd.read_csv("indian_engineering_student_placement.csv")

# %%
df.head()
# Out:
#    Student_ID  gender branch  cgpa  tenth_percentage  twelfth_percentage  \
# 0           1    Male    ECE  8.74              74.0                75.0
# 1           2  Female    ECE  7.80              75.3                69.7
# 2           3  Female     IT  6.95              62.8                68.3
# 3           4    Male    ECE  7.46              57.9                51.4
# 4           5    Male     IT  6.86              61.3                73.5
#
#    backlogs  study_hours_per_day  attendance_percentage  projects_completed  \
# 0         0                  3.8                   71.1                   7
# 1         0                  6.3                   69.5                   5
# 2         0                  1.5                   62.5                   8
# 3         1                  4.7                   64.6                   6
# 4         2                  5.2                   75.9                   3
#
# ...

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.dtypes
# Out:
# Student_ID                       int64
# gender                             str
# branch                             str
# cgpa                           float64
# tenth_percentage               float64
# twelfth_percentage             float64
# backlogs                         int64
# study_hours_per_day            float64
# attendance_percentage          float64
# projects_completed               int64
# internships_completed            int64
# coding_skill_rating              int64
# communication_skill_rating       int64
# aptitude_skill_rating            int64
# hackathons_participated          int64
# certifications_count             int64
# sleep_hours                    float64
# stress_level                     int64
# part_time_job                      str
# family_income_level                str
# city_tier                          str
# internet_access                    str
# extracurricular_involvement        str
# dtype: object

# %% [markdown]
# #### ***Integer data  description fetch out by using simple describe***

# %%
df.describe()
# Out:
#         Student_ID         cgpa  tenth_percentage  twelfth_percentage  \
# count  5000.000000  5000.000000       5000.000000         5000.000000
# mean   2500.500000     8.283798         74.537400           74.543060
# std    1443.520003     1.008391         10.266752           10.244481
# min       1.000000     5.000000         50.000000           50.000000
# 25%    1250.750000     7.610000         67.400000           67.600000
# 50%    2500.500000     8.320000         74.700000           74.800000
# 75%    3750.250000     9.020000         82.000000           81.700000
# max    5000.000000    10.000000        100.000000          100.000000
#
#           backlogs  study_hours_per_day  attendance_percentage  \
# count  5000.000000          5000.000000            5000.000000
# mean      0.343600             4.041120              72.041560
# std       0.612547             1.967754               7.720029
# min       0.000000             0.000000              44.700000
# ...

# %%
df.dtypes
# Out:
# Student_ID                       int64
# gender                             str
# branch                             str
# cgpa                           float64
# tenth_percentage               float64
# twelfth_percentage             float64
# backlogs                         int64
# study_hours_per_day            float64
# attendance_percentage          float64
# projects_completed               int64
# internships_completed            int64
# coding_skill_rating              int64
# communication_skill_rating       int64
# aptitude_skill_rating            int64
# hackathons_participated          int64
# certifications_count             int64
# sleep_hours                    float64
# stress_level                     int64
# part_time_job                      str
# family_income_level                str
# city_tier                          str
# internet_access                    str
# extracurricular_involvement        str
# dtype: object

# %% [markdown]
# #### ***To fetch out description of categorical we use two method***
# ##### ***One method write manually name of attribute***
# ##### ***Second is to convert it into index then use describe***

# %%
df[['gender','branch','part_time_job','family_income_level','city_tier','internet_access','extracurricular_involvement']]
# Out:
#       gender branch part_time_job family_income_level city_tier  \
# 0       Male    ECE           Yes              Medium    Tier 2
# 1     Female    ECE           Yes              Medium    Tier 3
# 2     Female     IT            No                 Low    Tier 2
# 3       Male    ECE            No              Medium    Tier 1
# 4       Male     IT            No              Medium    Tier 1
# ...      ...    ...           ...                 ...       ...
# 4995  Female     IT            No              Medium    Tier 3
# 4996    Male     IT            No                 Low    Tier 1
# 4997    Male     IT           Yes                 Low    Tier 2
# 4998  Female    ECE            No              Medium    Tier 2
# 4999    Male    CSE            No                 Low    Tier 1
#
#      internet_access extracurricular_involvement
# 0                Yes                      Medium
# 1                Yes                         Low
# ...

# %%
df.dtypes == 'str'
# Out:
# Student_ID                     False
# gender                          True
# branch                          True
# cgpa                           False
# tenth_percentage               False
# twelfth_percentage             False
# backlogs                       False
# study_hours_per_day            False
# attendance_percentage          False
# projects_completed             False
# internships_completed          False
# coding_skill_rating            False
# communication_skill_rating     False
# aptitude_skill_rating          False
# hackathons_participated        False
# certifications_count           False
# sleep_hours                    False
# stress_level                   False
# part_time_job                   True
# family_income_level             True
# city_tier                       True
# internet_access                 True
# extracurricular_involvement     True
# dtype: bool

# %%
df.dtypes[df.dtypes == 'str'].index
# Out:
# Index(['gender', 'branch', 'part_time_job', 'family_income_level', 'city_tier',
#        'internet_access', 'extracurricular_involvement'],
#       dtype='str')

# %%
df[df.dtypes[df.dtypes == 'str'].index].describe()
# Out:
#        gender branch part_time_job family_income_level city_tier  \
# count    5000   5000          5000                5000      5000
# unique      2      5             2                   3         3
# top      Male    CSE            No              Medium    Tier 2
# freq     2999   1522          4007                2466      2023
#
#        internet_access extracurricular_involvement
# count             5000                        3994
# unique               2                           3
# top                Yes                      Medium
# freq              4461                        1501

# %%
df.dtypes
# Out:
# Student_ID                       int64
# gender                             str
# branch                             str
# cgpa                           float64
# tenth_percentage               float64
# twelfth_percentage             float64
# backlogs                         int64
# study_hours_per_day            float64
# attendance_percentage          float64
# projects_completed               int64
# internships_completed            int64
# coding_skill_rating              int64
# communication_skill_rating       int64
# aptitude_skill_rating            int64
# hackathons_participated          int64
# certifications_count             int64
# sleep_hours                    float64
# stress_level                     int64
# part_time_job                      str
# family_income_level                str
# city_tier                          str
# internet_access                    str
# extracurricular_involvement        str
# dtype: object

# %%
df[df.dtypes[df.dtypes == 'float'].index]
# Out:
#        cgpa  tenth_percentage  twelfth_percentage  study_hours_per_day  \
# 0      8.74              74.0                75.0                  3.8
# 1      7.80              75.3                69.7                  6.3
# 2      6.95              62.8                68.3                  1.5
# 3      7.46              57.9                51.4                  4.7
# 4      6.86              61.3                73.5                  5.2
# ...     ...               ...                 ...                  ...
# 4995  10.00              90.4                98.3                  3.7
# 4996   7.76              74.3                72.6                  6.3
# 4997   7.79              64.0                71.2                  2.0
# 4998   8.76              74.3                74.0                  5.1
# 4999   9.45              85.6                80.0                  2.8
#
#       attendance_percentage  sleep_hours
# 0                      71.1          6.5
# ...

# %%
df.columns
# Out:
# Index(['Student_ID', 'gender', 'branch', 'cgpa', 'tenth_percentage',
#        'twelfth_percentage', 'backlogs', 'study_hours_per_day',
#        'attendance_percentage', 'projects_completed', 'internships_completed',
#        'coding_skill_rating', 'communication_skill_rating',
#        'aptitude_skill_rating', 'hackathons_participated',
#        'certifications_count', 'sleep_hours', 'stress_level', 'part_time_job',
#        'family_income_level', 'city_tier', 'internet_access',
#        'extracurricular_involvement'],
#       dtype='str')

# %%
df[['cgpa','gender']][4:11:2]
# Out:
#     cgpa  gender
# 4   6.86    Male
# 6   8.26    Male
# 8   7.97  Female
# 10  6.77    Male

# %%
df['new_col']=0

# %%
df
# Out:
#       Student_ID  gender branch   cgpa  tenth_percentage  twelfth_percentage  \
# 0              1    Male    ECE   8.74              74.0                75.0
# 1              2  Female    ECE   7.80              75.3                69.7
# 2              3  Female     IT   6.95              62.8                68.3
# 3              4    Male    ECE   7.46              57.9                51.4
# 4              5    Male     IT   6.86              61.3                73.5
# ...          ...     ...    ...    ...               ...                 ...
# 4995        4996  Female     IT  10.00              90.4                98.3
# 4996        4997    Male     IT   7.76              74.3                72.6
# 4997        4998    Male     IT   7.79              64.0                71.2
# 4998        4999  Female    ECE   8.76              74.3                74.0
# 4999        5000    Male    CSE   9.45              85.6                80.0
#
# ...

# %%
df["new-col1"]=df['backlogs'] + df['projects_completed']

# %%
df
# Out:
#       Student_ID  gender branch   cgpa  tenth_percentage  twelfth_percentage  \
# 0              1    Male    ECE   8.74              74.0                75.0
# 1              2  Female    ECE   7.80              75.3                69.7
# 2              3  Female     IT   6.95              62.8                68.3
# 3              4    Male    ECE   7.46              57.9                51.4
# 4              5    Male     IT   6.86              61.3                73.5
# ...          ...     ...    ...    ...               ...                 ...
# 4995        4996  Female     IT  10.00              90.4                98.3
# 4996        4997    Male     IT   7.76              74.3                72.6
# 4997        4998    Male     IT   7.79              64.0                71.2
# 4998        4999  Female    ECE   8.76              74.3                74.0
# 4999        5000    Male    CSE   9.45              85.6                80.0
#
# ...

# %%
df.head()
# Out:
#    Student_ID  gender branch  cgpa  tenth_percentage  twelfth_percentage  \
# 0           1    Male    ECE  8.74              74.0                75.0
# 1           2  Female    ECE  7.80              75.3                69.7
# 2           3  Female     IT  6.95              62.8                68.3
# 3           4    Male    ECE  7.46              57.9                51.4
# 4           5    Male     IT  6.86              61.3                73.5
#
#    backlogs  study_hours_per_day  attendance_percentage  projects_completed  \
# 0         0                  3.8                   71.1                   7
# 1         0                  6.3                   69.5                   5
# 2         0                  1.5                   62.5                   8
# 3         1                  4.7                   64.6                   6
# 4         2                  5.2                   75.9                   3
#
# ...

# %%
pd.Categorical(df["certifications_count"])
# Out:
# [5, 1, 3, 2, 1, ..., 2, 2, 2, 5, 2]
# Length: 5000
# Categories (10, int64): [0, 1, 2, 3, ..., 6, 7, 8, 9]

# %%
pd.Categorical(df["backlogs"])
# Out:
# [0, 0, 0, 1, 2, ..., 0, 2, 2, 0, 0]
# Length: 5000
# Categories (6, int64): [0, 1, 2, 3, 4, 5]

# %%
df["branch"].unique()
# Out:
# <StringArray>
# ['ECE', 'IT', 'CSE', 'CE', 'ME']
# Length: 5, dtype: str

# %%
df.head()
# Out:
#    Student_ID  gender branch  cgpa  tenth_percentage  twelfth_percentage  \
# 0           1    Male    ECE  8.74              74.0                75.0
# 1           2  Female    ECE  7.80              75.3                69.7
# 2           3  Female     IT  6.95              62.8                68.3
# 3           4    Male    ECE  7.46              57.9                51.4
# 4           5    Male     IT  6.86              61.3                73.5
#
#    backlogs  study_hours_per_day  attendance_percentage  projects_completed  \
# 0         0                  3.8                   71.1                   7
# 1         0                  6.3                   69.5                   5
# 2         0                  1.5                   62.5                   8
# 3         1                  4.7                   64.6                   6
# 4         2                  5.2                   75.9                   3
#
# ...

# %%
df[df["cgpa"]>8.74]
# Out:
#       Student_ID  gender branch   cgpa  tenth_percentage  twelfth_percentage  \
# 9             10  Female    ECE   8.79              70.1                77.1
# 11            12  Female     CE   9.62              83.4                86.8
# 13            14    Male     ME   8.94              84.9                81.7
# 16            17    Male    CSE   8.97              76.3                84.0
# 18            19    Male     ME   9.06              78.0                82.3
# ...          ...     ...    ...    ...               ...                 ...
# 4992        4993    Male    ECE   8.76              74.5                76.6
# 4994        4995    Male    CSE  10.00              93.2                88.1
# 4995        4996  Female     IT  10.00              90.4                98.3
# 4998        4999  Female    ECE   8.76              74.3                74.0
# 4999        5000    Male    CSE   9.45              85.6                80.0
#
# ...

# %%
len(df[df["cgpa"]>8.74])
# Out:
# 1703

# %%
df[df["cgpa"]>8.283798]
# Out:
#       Student_ID  gender branch   cgpa  tenth_percentage  twelfth_percentage  \
# 0              1    Male    ECE   8.74              74.0                75.0
# 9             10  Female    ECE   8.79              70.1                77.1
# 11            12  Female     CE   9.62              83.4                86.8
# 13            14    Male     ME   8.94              84.9                81.7
# 15            16    Male    CSE   8.57              79.5                79.0
# ...          ...     ...    ...    ...               ...                 ...
# 4992        4993    Male    ECE   8.76              74.5                76.6
# 4994        4995    Male    CSE  10.00              93.2                88.1
# 4995        4996  Female     IT  10.00              90.4                98.3
# 4998        4999  Female    ECE   8.76              74.3                74.0
# 4999        5000    Male    CSE   9.45              85.6                80.0
#
# ...

# %%
df[df["cgpa"]==0]
# Out:
# Empty DataFrame
# Columns: [Student_ID, gender, branch, cgpa, tenth_percentage, twelfth_percentage, backlogs, study_hours_per_day, attendance_percentage, projects_completed, internships_completed, coding_skill_rating, communication_skill_rating, aptitude_skill_rating, hackathons_participated, certifications_count, sleep_hours, stress_level, part_time_job, family_income_level, city_tier, internet_access, extracurricular_involvement, new_col, new-col1]
# Index: []
#
# [0 rows x 25 columns]

# %%
df
# Out:
#       Student_ID  gender branch   cgpa  tenth_percentage  twelfth_percentage  \
# 0              1    Male    ECE   8.74              74.0                75.0
# 1              2  Female    ECE   7.80              75.3                69.7
# 2              3  Female     IT   6.95              62.8                68.3
# 3              4    Male    ECE   7.46              57.9                51.4
# 4              5    Male     IT   6.86              61.3                73.5
# ...          ...     ...    ...    ...               ...                 ...
# 4995        4996  Female     IT  10.00              90.4                98.3
# 4996        4997    Male     IT   7.76              74.3                72.6
# 4997        4998    Male     IT   7.79              64.0                71.2
# 4998        4999  Female    ECE   8.76              74.3                74.0
# 4999        5000    Male    CSE   9.45              85.6                80.0
#
# ...

# %%
df[df['gender']=='Male']
# Out:
#       Student_ID gender branch   cgpa  tenth_percentage  twelfth_percentage  \
# 0              1   Male    ECE   8.74              74.0                75.0
# 3              4   Male    ECE   7.46              57.9                51.4
# 4              5   Male     IT   6.86              61.3                73.5
# 5              6   Male    CSE   7.46              70.5                70.4
# 6              7   Male     CE   8.26              81.2                74.8
# ...          ...    ...    ...    ...               ...                 ...
# 4992        4993   Male    ECE   8.76              74.5                76.6
# 4994        4995   Male    CSE  10.00              93.2                88.1
# 4996        4997   Male     IT   7.76              74.3                72.6
# 4997        4998   Male     IT   7.79              64.0                71.2
# 4999        5000   Male    CSE   9.45              85.6                80.0
#
# ...

# %%
df[df['backlogs']==1]
# Out:
#       Student_ID  gender branch  cgpa  tenth_percentage  twelfth_percentage  \
# 3              4    Male    ECE  7.46              57.9                51.4
# 8              9  Female    CSE  7.97              71.4                73.8
# 15            16    Male    CSE  8.57              79.5                79.0
# 20            21  Female     ME  7.22              70.4                67.8
# 41            42    Male     ME  8.28              78.1                62.8
# ...          ...     ...    ...   ...               ...                 ...
# 4957        4958  Female     CE  7.69              69.3                72.3
# 4960        4961    Male     ME  7.97              75.7                71.0
# 4984        4985    Male     IT  7.48              73.5                64.2
# 4986        4987  Female    ECE  7.91              73.7                74.0
# 4989        4990  Female     IT  8.22              72.5                73.6
#
# ...

# %%
df["gender"]=='Female'
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 4995     True
# 4996    False
# 4997    False
# 4998     True
# 4999    False
# Name: gender, Length: 5000, dtype: bool

# %%
df[(df["cgpa"]>8.283798) & (df["gender"]=='Female')]
# Out:
#       Student_ID  gender branch   cgpa  tenth_percentage  twelfth_percentage  \
# 9             10  Female    ECE   8.79              70.1                77.1
# 11            12  Female     CE   9.62              83.4                86.8
# 30            31  Female    ECE   8.74              71.7                84.8
# 38            39  Female     CE   8.72              80.3                76.8
# 43            44  Female     ME   9.32              82.4                89.1
# ...          ...     ...    ...    ...               ...                 ...
# 4982        4983  Female    ECE   8.59              71.8                76.2
# 4988        4989  Female    CSE   8.32              64.5                73.7
# 4990        4991  Female    ECE  10.00              90.0                86.3
# 4995        4996  Female     IT  10.00              90.4                98.3
# 4998        4999  Female    ECE   8.76              74.3                74.0
#
# ...

# %%
df[df['Student_ID']==max(df['Student_ID'])]
# Out:
#       Student_ID gender branch  cgpa  tenth_percentage  twelfth_percentage  \
# 4999        5000   Male    CSE  9.45              85.6                80.0
#
#       backlogs  study_hours_per_day  attendance_percentage  \
# 4999         0                  2.8                   63.4
#
#       projects_completed  ...  certifications_count  sleep_hours  \
# 4999                   8  ...                     2          7.8
#
#       stress_level  part_time_job  family_income_level  city_tier  \
# 4999             1             No                  Low     Tier 1
#
#       internet_access  extracurricular_involvement new_col new-col1
# 4999               No                         High       0        8
#
# [1 rows x 25 columns]

# %%
df.head(4)
# Out:
#    Student_ID  gender branch  cgpa  tenth_percentage  twelfth_percentage  \
# 0           1    Male    ECE  8.74              74.0                75.0
# 1           2  Female    ECE  7.80              75.3                69.7
# 2           3  Female     IT  6.95              62.8                68.3
# 3           4    Male    ECE  7.46              57.9                51.4
#
#    backlogs  study_hours_per_day  attendance_percentage  projects_completed  \
# 0         0                  3.8                   71.1                   7
# 1         0                  6.3                   69.5                   5
# 2         0                  1.5                   62.5                   8
# 3         1                  4.7                   64.6                   6
#
#    ...  certifications_count  sleep_hours  stress_level  part_time_job  \
# 0  ...                     5          6.5             8            Yes
# 1  ...                     1          7.1             8            Yes
# ...

# %%
df[0:2]
# Out:
#    Student_ID  gender branch  cgpa  tenth_percentage  twelfth_percentage  \
# 0           1    Male    ECE  8.74              74.0                75.0
# 1           2  Female    ECE  7.80              75.3                69.7
#
#    backlogs  study_hours_per_day  attendance_percentage  projects_completed  \
# 0         0                  3.8                   71.1                   7
# 1         0                  6.3                   69.5                   5
#
#    ...  certifications_count  sleep_hours  stress_level  part_time_job  \
# 0  ...                     5          6.5             8            Yes
# 1  ...                     1          7.1             8            Yes
#
#    family_income_level  city_tier  internet_access  \
# 0               Medium     Tier 2              Yes
# 1               Medium     Tier 3              Yes
#
#    extracurricular_involvement new_col new-col1
# 0                       Medium       0        7
# ...

# %%
df[['cgpa','backlogs','projects_completed']][0:2]
# Out:
#    cgpa  backlogs  projects_completed
# 0  8.74         0                   7
# 1  7.80         0                   5

# %%
df.loc[0:2,['cgpa','backlogs','projects_completed']]
# Out:
#    cgpa  backlogs  projects_completed
# 0  8.74         0                   7
# 1  7.80         0                   5
# 2  6.95         0                   8

# %%
df.iloc[0:2,[3,6,9]]
# Out:
#    cgpa  backlogs  projects_completed
# 0  8.74         0                   7
# 1  7.80         0                   5
