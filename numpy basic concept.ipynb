# %% [markdown]
# ### <i>NumPy Basics</i>
#
# <small><i>Creating Arrays</i></small>
#
# <small><i>Using `np.array()`</i></small>
#
# <small><i>Using `np.asarray()`</i></small>
#
# <small><i>Using `np.asanyarray()`</i></small>
#
# <small><i>Matrix and Array Conversion</i></small>
#
# <small><i>Copy vs Reference</i></small>
#
# <small><i>Shallow Copy</i></small>
#
# <small><i>Deep Copy using `np.copy()`</i></small>
#
# <small><i>Creating Arrays with `np.fromfunction()`</i></small>
#
# <small><i>Creating Arrays with `np.fromiter()`</i></small>
#
# <small><i>Creating Arrays with `np.fromstring()`</i></small>
#
# <small><i>Array Properties (`ndim`, `size`, `shape`, `dtype`)</i></small>
#
# <small><i>Creating Arrays with `np.arange()`</i></small>
#
# <small><i>Creating Arrays with `np.linspace()`</i></small>
#
# <small><i>Summary</i></small>

# %%
import numpy as np

# %%
l=[1,2,3,4]

# %%
ar=np.array(l)

# %%
ar
# Out:
# array([1, 2, 3, 4])

# %%
type(ar)
# Out:
# numpy.ndarray

# %%
np.array([[1,2],[3,4]])
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.asarray(l)
# Out:
# array([1, 2, 3, 4])

# %%
a=[1,2,3,4]

# %%
np.asanyarray(a)
# Out:
# array([1, 2, 3, 4])

# %%
b=np.matrix(l)

# %%
b
# Out:
# matrix([[1, 2, 3, 4]])

# %%
np.asanyarray(b)
# Out:
# matrix([[1, 2, 3, 4]])

# %%
a=np.array(l)

# %%
c=a

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
c
# Out:
# array([1, 2, 3, 4])

# %%
c[0]=100

# %%
c
# Out:
# array([100,   2,   3,   4])

# %%
a
# Out:
# array([100,   2,   3,   4])

# %%
d=np.copy(a)

# %%
d
# Out:
# array([100,   2,   3,   4])

# %%
a[1]=400

# %%
a
# Out:
# array([100, 400,   3,   4])

# %%
d
# Out:
# array([100,   2,   3,   4])

# %%
np.fromfunction(lambda i,j :i==j,(3,3))
# Out:
# array([[ True, False, False],
#        [False,  True, False],
#        [False, False,  True]])

# %%
np.fromfunction(lambda i,j :i*j,(3,3))
# Out:
# array([[0., 0., 0.],
#        [0., 1., 2.],
#        [0., 2., 4.]])

# %%
iterable=(i*i for i in range(5))

# %%
np.fromiter(iterable,float)
# Out:
# array([ 0.,  1.,  4.,  9., 16.])

# %%
arr = np.fromstring("234 234", dtype=int, sep=' ')
print(arr)
# Out:
# [234 234]

# %%
arr.ndim
# Out:
# 1

# %%
arr.size
# Out:
# 2

# %%
arr.shape
# Out:
# (2,)

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
ar22=np.array([(1.4,45,66),(25,45,33)])

# %%
ar22
# Out:
# array([[ 1.4, 45. , 66. ],
#        [25. , 45. , 33. ]])

# %%
ar22.dtype
# Out:
# dtype('float64')

# %%
np.arange(1.2,9.0)
# Out:
# array([1.2, 2.2, 3.2, 4.2, 5.2, 6.2, 7.2, 8.2])

# %%
list(np.arange(2.3,5.6,.3))
# Out:
# [np.float64(2.3),
#  np.float64(2.5999999999999996),
#  np.float64(2.8999999999999995),
#  np.float64(3.1999999999999993),
#  np.float64(3.499999999999999),
#  np.float64(3.799999999999999),
#  np.float64(4.099999999999999),
#  np.float64(4.399999999999999),
#  np.float64(4.699999999999998),
#  np.float64(4.999999999999998),
#  np.float64(5.299999999999998)]

# %%
np.linspace(1,5,10)
# Out:
# array([1.        , 1.44444444, 1.88888889, 2.33333333, 2.77777778,
#        3.22222222, 3.66666667, 4.11111111, 4.55555556, 5.        ])

# %%
import numpy as np

# %%
l=[1,2,3,4]

# %%
ar=np.array(l)

# %%
ar
# Out:
# array([1, 2, 3, 4])

# %%
type(ar)
# Out:
# numpy.ndarray

# %%
np.array([[1,2],[3,4]])
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.asarray(l)
# Out:
# array([1, 2, 3, 4])

# %%
a=[1,2,3,4]

# %%
np.asanyarray(a)
# Out:
# array([1, 2, 3, 4])

# %%
b=np.matrix(l)

# %%
b
# Out:
# matrix([[1, 2, 3, 4]])

# %%
np.asanyarray(b)
# Out:
# matrix([[1, 2, 3, 4]])

# %%
a=np.array(l)

# %%
c=a

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
c
# Out:
# array([1, 2, 3, 4])

# %%
c[0]=100

# %%
c
# Out:
# array([100,   2,   3,   4])

# %%
a
# Out:
# array([100,   2,   3,   4])

# %%
d=np.copy(a)

# %%
d
# Out:
# array([100,   2,   3,   4])

# %%
a[1]=400

# %%
a
# Out:
# array([100, 400,   3,   4])

# %%
d
# Out:
# array([100,   2,   3,   4])

# %%
np.fromfunction(lambda i,j :i==j,(3,3))
# Out:
# array([[ True, False, False],
#        [False,  True, False],
#        [False, False,  True]])

# %%
np.fromfunction(lambda i,j :i*j,(3,3))
# Out:
# array([[0., 0., 0.],
#        [0., 1., 2.],
#        [0., 2., 4.]])

# %%
iterable=(i*i for i in range(5))

# %%
np.fromiter(iterable,float)
# Out:
# array([ 0.,  1.,  4.,  9., 16.])

# %%
arr = np.fromstring("234 234", dtype=int, sep=' ')
print(arr)
# Out:
# [234 234]

# %%
arr.ndim
# Out:
# 1

# %%
arr.size
# Out:
# 2

# %%
arr.shape
# Out:
# (2,)

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
ar22=np.array([(1.4,45,66),(25,45,33)])

# %%
ar22
# Out:
# array([[ 1.4, 45. , 66. ],
#        [25. , 45. , 33. ]])

# %%
ar22.dtype
# Out:
# dtype('float64')

# %%
np.arange(1.2,9.0)
# Out:
# array([1.2, 2.2, 3.2, 4.2, 5.2, 6.2, 7.2, 8.2])

# %%
list(np.arange(2.3,5.6,.3))
# Out:
# [np.float64(2.3),
#  np.float64(2.5999999999999996),
#  np.float64(2.8999999999999995),
#  np.float64(3.1999999999999993),
#  np.float64(3.499999999999999),
#  np.float64(3.799999999999999),
#  np.float64(4.099999999999999),
#  np.float64(4.399999999999999),
#  np.float64(4.699999999999998),
#  np.float64(4.999999999999998),
#  np.float64(5.299999999999998)]

# %%
np.linspace(1,5,10)
# Out:
# array([1.        , 1.44444444, 1.88888889, 2.33333333, 2.77777778,
#        3.22222222, 3.66666667, 4.11111111, 4.55555556, 5.        ])
