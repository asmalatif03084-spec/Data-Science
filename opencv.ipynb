# %%
import cv2

# %%
img=cv2.imread('assest/download.jpg',1)

# %% [markdown]
# ### **0=gray image,1=color image,-1=original image**

# %%
print(img)
# Out:
# [[  9   9   9 ... 152 152 153]
#  [  9   9   9 ... 160 160 160]
#  [  9   9   9 ... 134 134 135]
#  ...
#  [ 17  14  11 ... 176 169 160]
#  [ 18  15  11 ... 192 183 173]
#  [ 19  16  12 ... 185 176 166]]

# %%
import matplotlib.pyplot as plt

plt.imshow(img, cmap='gray')
plt.axis('off')
plt.show()

# %%
cv2.imwrite('new_image.jpg',img)
# Out:
# True

# %%
resize=cv2.resize(img,(300,300))

# %%
crop=img[50:200,100:250]

# %%
flip=cv2.flip(img,1)

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
print(hasattr(cv2, "cvtColor"))
# Out:
# True

# %%
cv2.line(img, (20,20), (200,20), (255,0,0), 2)

cv2.rectangle(img, (50,50), (200,200), (0,255,0), 2)

cv2.circle(img, (150,150), 40, (0,0,255), 2)
# Out:
# array([[[  7,   7,  13],
#         [  7,   7,  13],
#         [  7,   7,  13],
#         ...,
#         [ 97, 128, 219],
#         [ 88, 130, 219],
#         [ 79, 132, 222]],
#
#        [[  7,   7,  13],
#         [  7,   7,  13],
#         [  7,   7,  13],
#         ...,
#         [ 59, 135, 248],
#         [ 54, 136, 248],
#         [ 43, 138, 248]],
#
#        [[  7,   7,  13],
#         [  7,   7,  13],
#         [  7,   7,  13],
#         ...,
#         [ 52, 112, 208],
#         [ 47, 113, 208],
#         [ 39, 115, 211]],
#
#        ...,
#
#        [[ 22,  16,  17],
#         [ 19,  13,  14],
#         [ 15,  10,  11],
#         ...,
#         [160, 167, 200],
#         [155, 161, 190],
#         [149, 153, 178]],
#
#        [[ 23,  17,  18],
#         [ 20,  14,  15],
#         [ 15,  10,  11],
#         ...,
#         [128, 171, 255],
#         [123, 163, 246],
#         [118, 153, 233]],
#
#        [[ 24,  18,  19],
#         [ 21,  15,  16],
#         [ 16,  11,  12],
# ...

# %%
cv2.putText(img, "Hello", (50,50),
            cv2.FONT_HERSHEY_SIMPLEX,
            1, (255,255,255), 2)
# Out:
# array([[[  7,   7,  13],
#         [  7,   7,  13],
#         [  7,   7,  13],
#         ...,
#         [ 97, 128, 219],
#         [ 88, 130, 219],
#         [ 79, 132, 222]],
#
#        [[  7,   7,  13],
#         [  7,   7,  13],
#         [  7,   7,  13],
#         ...,
#         [ 59, 135, 248],
#         [ 54, 136, 248],
#         [ 43, 138, 248]],
#
#        [[  7,   7,  13],
#         [  7,   7,  13],
#         [  7,   7,  13],
#         ...,
#         [ 52, 112, 208],
#         [ 47, 113, 208],
#         [ 39, 115, 211]],
#
#        ...,
#
#        [[ 22,  16,  17],
#         [ 19,  13,  14],
#         [ 15,  10,  11],
#         ...,
#         [160, 167, 200],
#         [155, 161, 190],
#         [149, 153, 178]],
#
#        [[ 23,  17,  18],
#         [ 20,  14,  15],
#         [ 15,  10,  11],
#         ...,
#         [128, 171, 255],
#         [123, 163, 246],
#         [118, 153, 233]],
#
#        [[ 24,  18,  19],
#         [ 21,  15,  16],
#         [ 16,  11,  12],
# ...
