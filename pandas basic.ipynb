# %% [markdown]
# ### ***PANDAS BASICS***

# %%
import pandas as pd

# %%
pip install pd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### ***Read File***

# %%
pd.read_csv("indian_engineering_student_placement.csv")
# Out:
#       Student_ID  gender branch   cgpa  tenth_percentage  twelfth_percentage  \
# 0              1    Male    ECE   8.74              74.0                75.0
# 1              2  Female    ECE   7.80              75.3                69.7
# 2              3  Female     IT   6.95              62.8                68.3
# 3              4    Male    ECE   7.46              57.9                51.4
# 4              5    Male     IT   6.86              61.3                73.5
# ...          ...     ...    ...    ...               ...                 ...
# 4995        4996  Female     IT  10.00              90.4                98.3
# 4996        4997    Male     IT   7.76              74.3                72.6
# 4997        4998    Male     IT   7.79              64.0                71.2
# 4998        4999  Female    ECE   8.76              74.3                74.0
# 4999        5000    Male    CSE   9.45              85.6                80.0
#
# ...

# %% [markdown]
# #### ***Read from top***

# %%
df=pd.read_csv("indian_engineering_student_placement.csv")
df.head()
# Out:
#    Student_ID  gender branch  cgpa  tenth_percentage  twelfth_percentage  \
# 0           1    Male    ECE  8.74              74.0                75.0
# 1           2  Female    ECE  7.80              75.3                69.7
# 2           3  Female     IT  6.95              62.8                68.3
# 3           4    Male    ECE  7.46              57.9                51.4
# 4           5    Male     IT  6.86              61.3                73.5
#
#    backlogs  study_hours_per_day  attendance_percentage  projects_completed  \
# 0         0                  3.8                   71.1                   7
# 1         0                  6.3                   69.5                   5
# 2         0                  1.5                   62.5                   8
# 3         1                  4.7                   64.6                   6
# 4         2                  5.2                   75.9                   3
#
# ...

# %%
df.head(2)
# Out:
#    Student_ID  gender branch  cgpa  tenth_percentage  twelfth_percentage  \
# 0           1    Male    ECE  8.74              74.0                75.0
# 1           2  Female    ECE  7.80              75.3                69.7
#
#    backlogs  study_hours_per_day  attendance_percentage  projects_completed  \
# 0         0                  3.8                   71.1                   7
# 1         0                  6.3                   69.5                   5
#
#    ...  aptitude_skill_rating  hackathons_participated  certifications_count  \
# 0  ...                      5                        4                     5
# 1  ...                      3                        4                     1
#
#    sleep_hours  stress_level  part_time_job  family_income_level  city_tier  \
# 0          6.5             8            Yes               Medium     Tier 2
# 1          7.1             8            Yes               Medium     Tier 3
#
#   internet_access extracurricular_involvement
# ...

# %% [markdown]
# #### ***Read From Tail***

# %%
df.tail()
# Out:
#       Student_ID  gender branch   cgpa  tenth_percentage  twelfth_percentage  \
# 4995        4996  Female     IT  10.00              90.4                98.3
# 4996        4997    Male     IT   7.76              74.3                72.6
# 4997        4998    Male     IT   7.79              64.0                71.2
# 4998        4999  Female    ECE   8.76              74.3                74.0
# 4999        5000    Male    CSE   9.45              85.6                80.0
#
#       backlogs  study_hours_per_day  attendance_percentage  \
# 4995         0                  3.7                   75.3
# 4996         2                  6.3                   72.3
# 4997         2                  2.0                   63.8
# 4998         0                  5.1                   72.0
# 4999         0                  2.8                   63.4
#
#       projects_completed  ...  aptitude_skill_rating  hackathons_participated  \
# ...

# %%
df.tail(1)
# Out:
#       Student_ID gender branch  cgpa  tenth_percentage  twelfth_percentage  \
# 4999        5000   Male    CSE  9.45              85.6                80.0
#
#       backlogs  study_hours_per_day  attendance_percentage  \
# 4999         0                  2.8                   63.4
#
#       projects_completed  ...  aptitude_skill_rating  hackathons_participated  \
# 4999                   8  ...                      4                        6
#
#       certifications_count  sleep_hours  stress_level  part_time_job  \
# 4999                     2          7.8             1             No
#
#       family_income_level  city_tier internet_access  \
# 4999                  Low     Tier 1              No
#
#      extracurricular_involvement
# 4999                        High
#
# [1 rows x 23 columns]

# %% [markdown]
# #### ***Type Check***

# %%
type(df)
# Out:
# pandas.DataFrame

# %% [markdown]
# #### ***To See only Column***

# %%
list(df.columns)
# Out:
# ['Student_ID',
#  'gender',
#  'branch',
#  'cgpa',
#  'tenth_percentage',
#  'twelfth_percentage',
#  'backlogs',
#  'study_hours_per_day',
#  'attendance_percentage',
#  'projects_completed',
#  'internships_completed',
#  'coding_skill_rating',
#  'communication_skill_rating',
#  'aptitude_skill_rating',
#  'hackathons_participated',
#  'certifications_count',
#  'sleep_hours',
#  'stress_level',
#  'part_time_job',
#  'family_income_level',
#  'city_tier',
#  'internet_access',
#  'extracurricular_involvement']

# %%
df['branch']
# Out:
# 0       ECE
# 1       ECE
# 2        IT
# 3       ECE
# 4        IT
#        ...
# 4995     IT
# 4996     IT
# 4997     IT
# 4998    ECE
# 4999    CSE
# Name: branch, Length: 5000, dtype: str

# %%
type(df['branch'])
# Out:
# pandas.Series

# %%
list(df['branch'])
# Out:
# ['ECE',
#  'ECE',
#  'IT',
#  'ECE',
#  'IT',
#  'CSE',
#  'CE',
#  'IT',
#  'CSE',
#  'ECE',
#  'CSE',
#  'CE',
#  'ECE',
#  'ME',
#  'CSE',
#  'CSE',
#  'CSE',
#  'ECE',
#  'ME',
#  'IT',
#  'ME',
#  'ECE',
#  'IT',
#  'CE',
#  'IT',
#  'ECE',
#  'CSE',
#  'CSE',
#  'CE',
#  'CSE',
#  'ECE',
#  'ECE',
#  'ME',
#  'ME',
#  'CSE',
#  'ECE',
#  'ME',
#  'IT',
#  'CE',
#  'IT',
#  'CE',
#  'ME',
#  'CSE',
#  'ME',
#  'ME',
#  'ME',
#  'ECE',
#  'ECE',
#  'ECE',
#  'ECE',
#  'CSE',
#  'IT',
#  'CSE',
#  'CSE',
#  'ECE',
#  'ME',
#  'ECE',
#  'CSE',
#  'ME',
#  'ECE',
#  'IT',
#  'IT',
#  'ECE',
#  'ECE',
#  'CE',
#  'CSE',
#  'ECE',
#  'ECE',
#  'IT',
#  'CSE',
#  'ME',
#  'CE',
#  'ECE',
#  'CSE',
#  'IT',
#  'ECE',
#  'ME',
#  'CSE',
#  'ECE',
#  'ECE',
#  'CSE',
#  'CSE',
#  'IT',
#  'CSE',
#  'CSE',
#  'ECE',
#  'CE',
#  'CSE',
#  'ME',
#  'CSE',
#  'CSE',
#  'CSE',
#  'IT',
#  'CSE',
#  'CSE',
#  'ECE',
#  'IT',
#  'CSE',
#  'ECE',
#  'CSE',
#  'ECE',
#  'ME',
#  'ME',
#  'ECE',
# ...

# %%
df[['branch']]
# Out:
#      branch
# 0       ECE
# 1       ECE
# 2        IT
# 3       ECE
# 4        IT
# ...     ...
# 4995     IT
# 4996     IT
# 4997     IT
# 4998    ECE
# 4999    CSE
#
# [5000 rows x 1 columns]

# %%
type(df[['branch']])
# Out:
# pandas.DataFrame

# %%
df.columns
# Out:
# Index(['Student_ID', 'gender', 'branch', 'cgpa', 'tenth_percentage',
#        'twelfth_percentage', 'backlogs', 'study_hours_per_day',
#        'attendance_percentage', 'projects_completed', 'internships_completed',
#        'coding_skill_rating', 'communication_skill_rating',
#        'aptitude_skill_rating', 'hackathons_participated',
#        'certifications_count', 'sleep_hours', 'stress_level', 'part_time_job',
#        'family_income_level', 'city_tier', 'internet_access',
#        'extracurricular_involvement'],
#       dtype='str')

# %%
#to read multiple column we required name inside double list otherwise it will give error
df[['Student_ID','cgpa']]
# Out:
#       Student_ID   cgpa
# 0              1   8.74
# 1              2   7.80
# 2              3   6.95
# 3              4   7.46
# 4              5   6.86
# ...          ...    ...
# 4995        4996  10.00
# 4996        4997   7.76
# 4997        4998   7.79
# 4998        4999   8.76
# 4999        5000   9.45
#
# [5000 rows x 2 columns]

# %%
df.dtypes
# Out:
# Student_ID                       int64
# gender                             str
# branch                             str
# cgpa                           float64
# tenth_percentage               float64
# twelfth_percentage             float64
# backlogs                         int64
# study_hours_per_day            float64
# attendance_percentage          float64
# projects_completed               int64
# internships_completed            int64
# coding_skill_rating              int64
# communication_skill_rating       int64
# aptitude_skill_rating            int64
# hackathons_participated          int64
# certifications_count             int64
# sleep_hours                    float64
# stress_level                     int64
# part_time_job                      str
# family_income_level                str
# city_tier                          str
# internet_access                    str
# extracurricular_involvement        str
# dtype: object

# %%
pd.read_excel("file.xlsx")
# Out:
#    ID         Name Department        City  Salary            Join Date
# 0   1     Ali Khan      Sales     Karachi   55000  2023-01-01 00:00:00
# 1   2   Sara Ahmed         HR      Lahore   60000           15-02-2023
# 2   3   Usman Raza         IT   Islamabad   80000  2023-10-03 00:00:00
# 3   4  Ayesha Noor  Marketing     Karachi   65000  2023-05-04 00:00:00
# 4   5    Hamza Ali    Finance      Lahore   75000           20-05-2023
# 5   6   Zain Malik         IT  Faisalabad   70000  2023-12-06 00:00:00

# %%
df1= pd.read_excel("file.xlsx")
df1.dtypes
# Out:
# ID             int64
# Name             str
# Department       str
# City             str
# Salary         int64
# Join Date     object
# dtype: object

# %%
type(df1)
# Out:
# pandas.DataFrame

# %%
df1.columns
# Out:
# Index(['ID', 'Name', 'Department', 'City', 'Salary', 'Join Date'], dtype='str')

# %%
df1[['ID','Name']]
# Out:
#    ID         Name
# 0   1     Ali Khan
# 1   2   Sara Ahmed
# 2   3   Usman Raza
# 3   4  Ayesha Noor
# 4   5    Hamza Ali
# 5   6   Zain Malik

# %%
#df3.to_csv("file name") is tarah file jo url form mn hu usy save krskty hain
